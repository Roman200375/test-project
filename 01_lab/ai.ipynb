# %% [markdown]
# Початкова програма на Python

# %%
# Це є коментар, який не впливає на виконання програми.
# Мова програмування Python ігнорує рядки, які починаються з символу #.

# Ось наша перша програма на Python:
print("Привіт, світе!")

# Функція print() використовується для виведення тексту на екран.
# У цьому випадку вона виводить рядок "Привіт, світе!".
# Out:
# Привіт, світе!

# %% [markdown]
# В даному коді ми використовуємо функцію print() для виведення рядка "Привіт, світе!" на екран. Коментарі, починаючи з символу #, служать для пояснення коду і не впливають на його виконання.
#
# Пояснення які видав ChatGPT для роботи з Python Notebook (вставляємо відповідь від АІ)
# Щоб створити новий блок у Jupyter Notebook для вставки коду Python та пояснення у форматі Markdown, вам потрібно вставити код Python у блок з кодом та пояснення у блок з Markdown. Це може виглядати так:
#
# [Клітинка з кодом]
#
# Ваш код тут
# [Клітинка з Markdown]
#
# Ось наша програма. Вона виводить привітання на екран. Якщо у вас виникають додаткові запитання або потрібні додаткові пояснення, не соромтеся питати. Успішного вивчення програмування на Python!
#
# Як бачимо АІ тільки злегка нам допоміг, і ми як люди повинні розуміти що за інформацію Він видає та правильно нею користуватись.
#
# Вставляємо наступний запит про модифікацію програми від АІ
# Звісно, давайте модифікуємо нашу першу програму так, щоб вона використовувала змінні та дозволяла вводити значення з клавіатури.
#
# Змінні у Python
# Змінні у Python можна задавати локально (у межах функції або блоку коду) або глобально (на рівні всього скрипта). Ось приклади:
#
# Локальні змінні:
#
# Локальні змінні створюються та існують лише у межах функції або блоку коду, де вони були оголошені.

# %%
def my_function() -> str: 
    # Це локальна змінна, доступна лише у межах функції.
    local_variable = "Це локальна змінна"
    print(local_variable)
    return local_variable

value_from_function = my_function()  # Виклик функції
#print(local_variable)  # Генерує помилку, бо змінна local_variable не існує за межами функцїі.

print(f"Функція поверне значення: {value_from_function}") # Якщо ми повернемо значення локальної змінної та перезапишемо її у іншу змінну, т
# Out:
# Це локальна змінна
# Функція поверне значення: Це локальна змінна

# %% [markdown]
# Модифікована програма зі змінними та введенням значень з клавіатури
# Ось модифікований код програми з використанням змінних та введенням значень з клавіатури:

# %%
# Запитайте користувача про ім'я та збережіть його у змінній name
name = input("Будь ласка, введіть ваше ім'я: ")

# Виведіть привітання, використовуючи змінну name
print(f"Привіт, {name}!")

# Запитайте користувача про вік та збережіть його у змінній age
age = input("Скільки вам років? ")

# Виведіть вік користувача, використовуючи змінну age
print(f"Ваш вік: {age} років.")
# Out:
# Привіт, Роман!
# Ваш вік: 20 років.

# %% [markdown]
# У цьому коді ми використовуємо змінну name для збереження введеного користувачем імені та змінну age для збереження введеного віку. Функція input() використовується для отримання введення користувача з клавіатури. Команда print() використовує змінні для виведення інформації на екран.
#
# Ця програма спершу запитає ім'я користувача, а потім його вік, і виведе відповіді на екрані.
#
# Ви можете вставити цей код у клітинку Jupyter Notebook і додати пояснення в клітинку Markdown, як я раніше пояснив.
#
# Що видав ChatGPT за моїм запитом
# Мій запит:
#
# Можеш написати початкову програму на Python, з поясненням у клітинках формату Markdown?
#
# Відповідь ChatGPT:
#
# Markdown клітина 1: Заголовок
# ----------------------------
# Це заголовок програми. Ми почнемо з найпростішої програми Python.
# Markdown клітина 2: Введення даних
# ------------------------------
# Спершу ми можемо запросити користувача ввести деякі дані.
# Використаємо функцію input(), щоб отримати рядок від користувача і зберегти його у змінній.
# ім'я = input("Введіть ваше ім'я: ")
#
# Markdown клітина 3: Виведення даних
# ------------------------------
# Тепер ми можемо вивести ім'я користувача на екран.
# Використаємо функцію print() для виведення повідомлення на екран.
# print("Привіт, " + ім'я + "! Це початкова програма на Python.")
#
# Markdown клітина 4: Завершення програми
# -----------------------------------
# Ось і вся програма! Вона просто запитує ім'я користувача і виводить привітання.
# Markdown клітина 5: Висновок
# --------------------------
# Це базовий приклад Python-програми з введенням та виведенням даних. Python - дуже потужна мова програмування, і це тільки початок. Ви можете вчитися і розширювати свої навички, створюючи більш складні програми і розвиваючи свої проекти!
